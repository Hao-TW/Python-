# %%
import numpy as np
import pandas as pd
import matplotlib.pyplt as pit

y = np.sin(5*x)/(1+x**2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-595e26e9f332> in <module>
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import matplotlib.pyplt as pit
#       4
#       5 y = np.sin(5*x)/(1+x**2)
#
# ModuleNotFoundError: No module named 'matplotlib.pyplt'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
x = np.linspace(0,10,200)
y = np.sin(5*x)/(1+x**2)

plt.plot(x, y)
plt.show()

# %%
x = np.linspace(0,10,150)
y = np.sin(5*x)/(1+x**2)

plt.plot(x, y,'g-.')
plt.show()

# %%
x = np.linspace(0,10,200)
y = np.sin(5*x)/(1+x**2)

plt.plot(x, y,c='#00a676',lw=10,ls=':')
plt.show()

# %%
x = np.linspace(0,10,200)
y = np.sin(5*x)/(1+x**2)

plt.plot(x, y)

# %%
x=range(20)
y=np.random.randn(20)
plt.plot(x,y,marker='o')

# %%
plt.plot(x,y,c='#00c00c',lw=2,marker='o',mfc='#c14',mec='#095a45',mew=0.1,ms=10)

# %%
plt.plot([1,2,3,4],[1,4,9,16],'rs')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
plt.bar(range(1,6),np.random.randint(1,30,5))
# Out:
# <BarContainer object of 5 artists>

# %%
data = [73, 71, 34, 85, 80, 100, 57, 78, 88, 98, 
        46, 34, 74, 86, 41, 54, 80, 40, 71, 46, 
        43, 51, 58, 61, 71, 70, 65, 39, 28, 62, 
        49, 89, 73, 38, 41, 51, 45, 64, 51, 34, 
        42, 58, 67, 56, 71, 45, 32, 42, 59, 98, 
        33, 64, 55, 67, 50, 45, 64, 63, 85, 39, 
        48, 62, 34, 67, 100, 58, 68, 34, 38, 70, 
        64, 74, 62, 73, 45, 17, 68, 26, 69, 56, 
        76, 59, 45, 95, 78, 77, 70, 59, 91, 79, 
        53, 78, 61, 84, 56, 96, 68, 64, 46, 70]


data=np.array(data)
bins =np.linspace(np.ceil(min(data)),np.floor(max(data)),20)
plt.hist(data,bins,color='r',alpha=0.5)
plt.xlim([0,100])
plt.xlabel('Score',size=14)
plt.ylabel('Quantity',size=14)
plt.title('owo ',size=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x=np.arange(1,6)
plt.bar(x-0.4,[3,10,8,12,6],width=0.4,ec='none',fc='#fa9191')
plt.bar(x,[6,3,12,5,8],width=0.4,ec='none',fc='#4d3e3e')
# Out:
# <BarContainer object of 5 artists>

# %%
data=[5,20,15,25,10]
plt.bar(range(len(data)),data,ec='#be9fe1',ls='--',lw=2,color='rgb') #or 'color=['r','g','b']'
plt.show()
# Out:
# C:\ProgramData\Anaconda3\envs\work\lib\site-packages\ipykernel_launcher.py:2: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated. Use an explicit list instead.

# %%
plt.bar(range(len(data)),data,ec='k',lw=1,hatch='\\\\\\\\')
plt.show()

# %%
hatch -> 設置填充樣式
/,\,|,-,+,x,o,.
tick_label -> xlabel 設置為str
# Out:
#   File "<ipython-input-102-9b3ec5b5f73e>", line 1
#     hatch -> 設置填充樣式
#            ^
# SyntaxError: invalid syntax

# %%
labels=['Tom','Peter','Andy','Joy','Marry']
plt.bar(range(len(data)),data,tick_label=labels)
plt.show()

# %%
#bottom參數,可以繪製堆疊bar

size=5
x=np.arange(size)
a=np.random.random(size)
b=np.random.random(size)
plt.bar(x,a,label='a')
plt.bar(x,b,bottom=a,label='b')
plt.legend()
plt.show()

# %%
A=np.random.randint(2,15,5)
B=np.random.randint(2,15,5)
C=np.random.randint(2,15,5)

plt.bar(x,A,fc='#fa163f',ec='none')
plt.bar(x,B,fc='#0fabbc',ec='none',bottom=A)
plt.bar(x,C,fc='#12cad6',ec='none',bottom=A+B)
plt.show()

# %%
data = [5,20,15,25,10]
plt.barh(range(len(data)),data,fc='#4a69dd')
plt.show()

# %%
a=np.array([5,20,15,25,10])
b=np.array([10,15,25,5,10])

plt.barh(range(len(a)),a)
plt.barh(range(len(b)),-b)
plt.show()
