# %%
from bs4 import BeautifulSoup

from urllib.request import urlopen

html = urlopen('https://en.wikipedia.org/wiki/Kevin_Bacon').read().decode('utf-8')
soup = BeautifulSoup(html,features='lxml')

text_links = soup.find_all('a')
for link in text_links:
    print(link.get_text())
# Out:
# Jump to navigation
# Jump to search
# Kevin Bacon (disambiguation)
#
# Philadelphia
# Pennsylvania
# Kyra Sedgwick
# Sosie Bacon
# [1]
# Edmund Bacon
# Michael Bacon
# Holly Near
# baconbros.com
# [2]
# [3]
# Footloose
# JFK
# A Few Good Men
# Apollo 13
# Mystic River
# Sleepers
# The Woodsman
# National Lampoon's Animal House
# Diner
# Tremors
# Crazy, Stupid, Love
# Friday the 13th
# Flatliners
# The River Wild
# Wild Things
# Stir of Echoes
# Hollow Man
# Frost/Nixon
# X-Men: First Class
# Black Mass
# Patriots Day
# Fox
# The Following
# HBO
# Taking Chance
# Golden Globe Award
# Screen Actors Guild Award
# Primetime Emmy Award
# I Love Dick
# Golden Globe Award
# The Guardian
# Academy Award
# [4]
# Hollywood Walk of Fame
# [5]
# social networks
# Six Degrees of Kevin Bacon
# SixDegrees.org
# [6]
# 1 Early life and education
# 2 Acting career
# 2.1 Early work
# 2.2 1980s
# 2.3 1990s
# 2.4 2000s
# 2.5 2010s
# 2.6 Advertising work
# 3 Personal life
# 4 Six Degrees of Kevin Bacon
# ...

# %%
import re

html = urlopen('https://morvanzhou.github.io/static/scraping/table.html').read().decode('utf-8')
soup = BeautifulSoup(html)

img_links = soup.find_all('img',{'src':re.compile('.*?\.jpg')})

for link in img_links:
    print(link['src'])
print('\n')
course_link=soup.find_all('a',{'href':re.complile('https://morvanzhou.github.io/tutorials/machine-learning/tensorflow')})
for link in course_link:
    print(link['href'])
# Out:
# https://morvanzhou.github.io/static/img/course_cover/tf.jpg
# https://morvanzhou.github.io/static/img/course_cover/rl.jpg
# https://morvanzhou.github.io/static/img/course_cover/scraping.jpg
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-0e142d49d162> in <module>()
#       9     print(link['src'])
#      10 print('\n')
# ---> 11 course_link=soup.find_all('a',{'href':re.complile('https://morvanzhou.github.io/tutorials/machine-learning/tensorflow')})
#      12 for link in course_link:
#      13     print(link['href'])
#
# AttributeError: module 're' has no attribute 'complile'

# %%
#使用正規表達式
import requests
import re
from bs4 import BeautifulSoup
def main():
    resp = requests.get('http://jwlin.github.io/py-scraping-analysis-book/ch2/blog/blog.html')
    soup = BeautifulSoup(resp.text,'html.parser')
    titles = soup.find_all(['h1','h2','h3','h4','h5','h6'])
    for title in titles:
        print(title.text.strip())
        
    for title in soup.find_all(re.compile('h[1-6]')):
        print(title.text.strip())
    #找出所有.png結尾的圖片
    imgs = soup.find_all('img')
    for img in imgs:
        if 'src' in img.attrs:
            if img['src'].endswith('.png'):
                print(img['src'])
    #透過這則表達式
    for img in soup.find_all('img',{'src':re.compile('\.png$')}):
        print(img['src'])
    
if __name__ == '__main__':
    main()
# Out:
# Python教學文章
# 開發環境設定
# Mac使用者
# 資料科學
# 給初學者的 Python 網頁爬蟲與資料分析
# 資料科學
# 給初學者的 Python 網頁爬蟲與資料分析
# 資料科學
# 給初學者的 Python 網頁爬蟲與資料分析
# 資料科學
# 給初學者的 Python 網頁爬蟲與資料分析
# 資料科學
# 給初學者的 Python 網頁爬蟲與資料分析
# Python教學文章
# 開發環境設定
# Mac使用者
# 資料科學
# 給初學者的 Python 網頁爬蟲與資料分析
# 資料科學
# 給初學者的 Python 網頁爬蟲與資料分析
# 資料科學
# 給初學者的 Python 網頁爬蟲與資料分析
# 資料科學
# 給初學者的 Python 網頁爬蟲與資料分析
# 資料科學
# 給初學者的 Python 網頁爬蟲與資料分析
# static/python-for-beginners.png
# static/python_crawler.png
# static/python_crawler.png
# static/python_crawler.png
# static/python_crawler.png
# static/python_crawler.png
# static/python-for-beginners.png
# static/python_crawler.png
# static/python_crawler.png
# static/python_crawler.png
# static/python_crawler.png
# static/python_crawler.png

# %%
import requests
url='http://www.deepstone.com.tw'
try:
    htmlfile = requests.get(url)
    print('下載成功')
except Excetion as error:
    print("網頁原始碼下載失敗: %s" % err)
    
#儲存檢視的內容
fn = 'output.txt'
with open(fn,'wb') as file_Obj:
    for diskStorage in htmlfile.iter_content(10240):
        size = file_Obj.write(diskStorage)
        print(size)
    print("以 %s 儲存網頁HTML檔案成功" % fn)
# Out:
# 下載成功
# 10240
# 10240
# 7961
# 以 output.txt 儲存網頁HTML檔案成功

# %%
url = ''
html = requests.get(url)
sp = BeautifulSoup(html.text,'html.parser')
print(sp.select('title')[0].text.strip())
print(sp.find('span'),{'id':'ct108_labText1'}).text.strip())

print(sp.find('a',{'href':'HourlyData.aspx'}).get('title').strip())
rs = sp.find_all('tr',{'align':'center','style':'border-width:1px;border-style:solid'})
for r in rs:
    name = r.find_all('span')
    pm2.5 = r.
